# %% [markdown]
# # <font color = "Blue"> Examen III</font>
# ##### <font color = "DarkBlue"> Data Science Bootcamp - Math and Stats </font>
# ##### <font color = "DarkBlue"> 28th, February 2021 </font>
# ##### <font color = "DarkBlue"> Prof. Dr. Juanjo Manjarín </font>
# ----
#
# Use the following cell to load all the modules of the exam

# %% [markdown]
# and now connect to the drive in case you are using colab

# %% [markdown]
# ## Groceries
#
# **The owners of a grocer's shop has generated a small dataset containing different tickets from a set of customers (find it under the name `groceries.csv` in the exam folder). Find different patterns in the dataset using the *association rules* and explain them. For this you will have to decide and explain the following**
#
#  * **Select a support threshold**
#  * **A threshold from a metric and arange rules from it**
#
# **Once you have found some relevant rules, explain them and explain to the owner the different behaviours of his customers**

# %% [markdown]
# ## NBA Longevity
#
# **The dataset `nba_longevity.csv` contains some statistics of different NBA basketball players (the meaning of the names of the variables can be found in any basketball statistics page). The aim of this analysis is to create a Naïve Bayes classiffier that may let you understand from those statistics whether or not the player will last 5 years playing at the highest level. Then follow the next questions**

# %% [markdown]
# **Load the dataset**

# %% [markdown]
# ### Train/Test
#
# **Use either hold-out sets or cross-validation to perform a train/test split in the dataset**

# %% [markdown]
# ### Model
#
# **Define a first model that you can later use**

# %% [markdown]
# ### Learning/Validation
#
# **Find the learning and validation curves and explain their meaning. Would you change anything from your model based on this information? If so, do it and contunue with that model**

# %% [markdown]
# ### Predictions
#
# **Find the predicted output from your model**

# %% [markdown]
# ### Metrics
#
# **Evaluate the model using the common metrics. Explain what these tell you about the model**

# %% [markdown]
# ### ROC/PR Curves
#
# **Find the ROC and PR curves and explain them**
